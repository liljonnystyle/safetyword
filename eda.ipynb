# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('data/training.csv')
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
df.shape
# Out:
# (250000, 33)

# %%
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
for i in xrange(30):
    df = df[df.iloc[:,i] >= -998]
df.describe()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   68114.000000  68114.000000                 68114.000000  68114.000000
# mean   225035.224154    122.816184                    35.270300     78.496815
# std     72243.940540     60.751559                    30.750262     40.728784
# min    100000.000000      9.878000                     0.000000      7.330000
# 25%    162349.750000     93.320250                    11.320000     57.274250
# 50%    225288.000000    113.230000                    26.964000     70.930000
# 75%    287772.750000    133.455750                    52.202750     88.372000
# max    349994.000000    988.199000                   594.287000    789.538000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  68114.000000          68114.000000      68114.000000
# mean     111.430393              2.434232        378.176455
# std       76.318688              1.750700        400.784254
# ...

# %%
cols = ['DER_mass_MMC','DER_mass_transverse_met_lep','DER_pt_h','DER_deltaeta_jet_jet','DER_mass_jet_jet','DER_prodeta_jet_jet',
        'DER_sum_pt','DER_pt_ratio_lep_tau','DER_met_phi_centrality','DER_lep_eta_centrality','PRI_tau_pt','PRI_met_sumet',
        'PRI_jet_num','PRI_jet_leading_pt','PRI_jet_leading_eta','PRI_jet_leading_phi','PRI_jet_subleading_pt',
        'PRI_jet_subleading_eta','PRI_jet_subleading_phi','PRI_jet_all_pt']

# %%
# pd.scatter_matrix(df[cols].iloc[:100,:],figsize=(20,20));

# %%
df.columns
# Out:
# Index([u'EventId', u'DER_mass_MMC', u'DER_mass_transverse_met_lep', u'DER_mass_vis', u'DER_pt_h', u'DER_deltaeta_jet_jet', u'DER_mass_jet_jet', u'DER_prodeta_jet_jet', u'DER_deltar_tau_lep', u'DER_pt_tot', u'DER_sum_pt', u'DER_pt_ratio_lep_tau', u'DER_met_phi_centrality', u'DER_lep_eta_centrality', u'PRI_tau_pt', u'PRI_tau_eta', u'PRI_tau_phi', u'PRI_lep_pt', u'PRI_lep_eta', u'PRI_lep_phi', u'PRI_met', u'PRI_met_phi', u'PRI_met_sumet', u'PRI_jet_num', u'PRI_jet_leading_pt', u'PRI_jet_leading_eta', u'PRI_jet_leading_phi', u'PRI_jet_subleading_pt', u'PRI_jet_subleading_eta', u'PRI_jet_subleading_phi', u'PRI_jet_all_pt', u'Weight', u'Label'], dtype='object')

# %%
df['Label_bin'] = np.where(df['Label'] == 's', 1, 0)

# %%
# corrdf = df.corr(method='pearson')

# %%
# corrdf.iloc[-1,:]

# %%
cols = ['DER_mass_transverse_met_lep','DER_pt_h','DER_deltaeta_jet_jet','DER_mass_jet_jet','DER_prodeta_jet_jet',
        'DER_pt_tot','DER_pt_ratio_lep_tau','DER_met_phi_centrality','DER_lep_eta_centrality','PRI_tau_pt','PRI_jet_num']

# %%
plt.figure(figsize=(15,20))

for i, col in enumerate(cols):
    plt.subplot(4,3,i+1)
    df[df['Label_bin'] == 1][col].hist(bins=50,color='r',alpha = 0.4)
    df[df['Label_bin'] == 0][col].hist(bins=50,color='b',alpha = 0.4)
    plt.title(col)

# %%
df[df['Label_bin'] == 1].iloc[:-3].describe()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   31891.000000  31891.000000                 31891.000000  31891.000000
# mean   225253.967765    123.982601                    27.460920     77.106131
# std     72196.791765     26.058521                    23.646554     20.716997
# min    100000.000000     17.090000                     0.003000     13.368000
# 25%    162393.500000    110.453000                     8.958500     63.775500
# 50%    225665.000000    122.728000                    21.151000     76.430000
# 75%    287862.500000    134.941000                    40.408500     89.676500
# max    349976.000000    977.333000                   242.246000    789.538000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  31891.000000          31891.000000      31891.000000
# mean     122.432318              3.035172        509.386309
# std       79.859053              1.922222        495.239656
# ...

# %%
df[df['Label_bin'] == 0].iloc[:-3].describe()
# Out:
#              EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   36217.000000  36217.000000                 36217.000000  36217.000000
# mean   224821.909932    121.789538                    42.147377     79.722953
# std     72273.913758     79.628693                    34.422581     52.332037
# min    100005.000000      9.878000                     0.000000      7.330000
# 25%    162282.000000     83.716000                    14.357000     52.678000
# 50%    224924.000000     98.070000                    34.510000     65.149000
# 75%    287627.000000    126.936000                    63.083000     85.116000
# max    349943.000000    988.199000                   594.287000    734.995000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  36217.000000          36217.000000      36217.000000
# mean     101.747853              1.905286        262.675366
# std       71.679126              1.382983        240.051155
# ...

# %%
from scipy.stats import ttest_ind

print 'Difference in means normalized by standard errors\n'
for i, col in enumerate(cols):
    t_stat, pval = ttest_ind(df[df['Label_bin'] == 0][col], df[df['Label_bin'] == 1][col], equal_var = False)
#     stda = np.std(df[df['Label_bin'] == 0][col])
#     stdb = np.std(df[df['Label_bin'] == 1][col])
#     std = np.sqrt(stda**2 + stdb**2)
#     meana = np.mean(df[df['Label_bin'] == 0][col])
#     meanb = np.mean(df[df['Label_bin'] == 1][col])
#     dmean = (meana - meanb) / std
    #print meana, meanb, std
    print col + ':\n\t' + str(t_stat) + '\t' + str(pval)
# Out:
# Difference in means normalized by standard errors
#
# DER_mass_transverse_met_lep:
# 	65.5258406019	0.0
# DER_pt_h:
# 	-35.3790232207	1.4445222751e-271
# DER_deltaeta_jet_jet:
# 	-86.9896359273	0.0
# DER_mass_jet_jet:
# 	-80.9794567578	0.0
# DER_prodeta_jet_jet:
# 	76.8184484889	0.0
# DER_pt_tot:
# 	52.9006857239	0.0
# DER_pt_ratio_lep_tau:
# 	38.9190639959	0.0
# DER_met_phi_centrality:
# 	-61.5219701296	0.0
# DER_lep_eta_centrality:
# 	-84.3089127071	0.0
# PRI_tau_pt:
# 	-40.1153535105	0.0
# PRI_jet_num:
# 	52.6990899816	0.0

# %%
# pd.scatter_matrix(df[cols].iloc[:100,:],figsize=(20,20));
